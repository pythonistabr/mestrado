# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime as dt

# %%
cd /home/gus/Documentos/mestrado/dados-mestrado/dados-hycom
# Out:
# /home/gus/Documentos/mestrado/dados-mestrado/dados-hycom

# %%
dful = pd.read_csv("saidas1h/hycom_ul_total_ajustado1h.csv", delimiter=";")

# %%
dful.head()
# Out:
#    8m  16m  32m  40m                 time
# 0 NaN  NaN  NaN  NaN  2016-12-01 12:00:00
# 1 NaN  NaN  NaN  NaN  2016-12-01 13:00:00
# 2 NaN  NaN  NaN  NaN  2016-12-01 14:00:00
# 3 NaN  NaN  NaN  NaN  2016-12-01 15:00:00
# 4 NaN  NaN  NaN  NaN  2016-12-01 16:00:00

# %%
tempo = pd.to_datetime(dful.time, format="%Y-%m-%d %H:%M:%S");

# %%
plt.figure(figsize=(8,5), dpi=300)
plt.plot(tempo, dful['8m'], ".")
